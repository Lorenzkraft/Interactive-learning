# %%
from utils.FilePreparator import ADN_sequence_1, ADN_sequence_2
import Chatbot

# %% [markdown]
# # Start here
# Evolution is the story of change over time, and at the heart of it all is DNA. Just as a typo in a book can change its meaning, mutations in DNA can change the proteins it codes for, leading to different traits in living organisms. Today, we'll step into the shoes of evolutionary biologists and explore how even small changes in DNA sequences can lead to dramatic variations in the appearance of the affected organism. Get ready to dive deep into the code of life and uncover the mechanisms behind genetic evolution!
# # Biological Background
# ## The zebra fish
# Zebre poisson ...
#
# ## Biological translation
# One way to distinguish the two zebra fish gene sequences is to translate them into their corresponding protein. So let's first recap how the translation is done in theory.
#
# To translate a DNA sequence into the corresponding protein (chain of amino acids), two steps are required. First, we need to transcribe the DNA sequence into its complementary mRNA sequence.
# This is done in <span style="color:orange">Step 1:</span>
#
# The bases must be replaced by their counterparts and `A` is replaced by`U`:
#
# <div style="background-color: orange; padding: 10px;">
#     <table style="color: black;">
#         <tr>
#             <th>Brin 1</th>
#             <th>Brin 2</th>
#         </tr>
#         <tr>
#             <td>A</td>
#             <td>U</td>
#         </tr>
#         <tr>
#             <td>T</td>
#             <td>A</td>
#         </tr>
#         <tr>
#             <td>G</td>
#             <td>C</td>
#         </tr>
#         <tr>
#             <td>C</td>
#             <td>G</td>
#         </tr>
#     </table>
# </div>
#
#
#
#
# <span style="color:cyan">Step 2:</span>
# Now the mRNA sequence need be translated into the corresponding protein.
# In this step we use the genetic code to translate the sequence into the protein.
# <div style="background-color: lightblue">
#     <img src="./utils/genetic-code-RNA-BW.png" alt="Alt text" width="300"/>
# </div>
#
#
# ## Goals
# Since the translation would take far too long by hand, we want to write a program code with the programming language "Python" that does the work for us. You have never programmed before? No problem, just follow this template and you will learn:
# 1. intuitivly how to translate genetic code by hand.
# 2. interactively how to transfer your procedure to code.

# %% [markdown]
# # Task 1
# In the first Task our goal is to translate a short sequence of DNA by hand and transfer our procedure into program code:
#
# __1a\)__
# Transcribe the DNA sequence ``ADN = TACTCCTGT`` into the ``ARNm`` sequence according to <span style="color:orange">step 1</span> _by hand with pen und paper_.
#
# __1b\)__
# Inspect the following code, where a list is translated into french and try to understand what each line does.
# If you need help, open the ``Robofriend.ipynb`` file in a separate tab and start a conversation with the chatbot.
# It has no background information, so copy and paste it the code and ask if it can help you understanding the code.
#
# __1c\)__
# Based on your understanding and the help of the ``Chatbot``, modify the code so it transcribes the DNA sequence from __Task 1a__.
# Your Code should produce a sequence called ``ARNm``. Does it match your result from __Task 1__?
# __If__ yes, you can proceed to the next Task,
# __else__ try to find the error yourself or ask your teacher for help.

# %%
courses_en_anglais = "apple banana pear grape ".split(" ") # remove .split(" ") when you modify the code for task 1c)

dictionaire_anglais_francais = {
    "apple": "pomme",
    "banana": "banane",
    "pear": "poire",
    "grape": "raisin"
}
courses_en_fr = ""

for item in courses_en_anglais:
    traduction_fr = dictionaire_anglais_francais.get(item, "")
    courses_en_fr += traduction_fr + " "
print(courses_en_fr)
# Out:
# pomme banane poire raisin

# %%
# Définis la séquence d'ADN que tu veux traduire.
ADN_sequence = "TACTCCTGT"

# %%
# Définir le dictionnaire du second brin de l'ADN.
Dictionaire_ADN_en_ARNm = {'A': 'U', 
                           'T': 'A', 
                           'G': 'C', 
                           'C': 'G'}

# %%
# Fonction de changement de brin d'ADN.
def switch_strand(ADN_sequence):
    ARNm_sequence = ""
    for nucleotide in ADN_sequence:
        ARNm_sequence += Dictionaire_ADN_en_ARNm.get(nucleotide, "")#[nucleotide]
    return ARNm_sequence
ARNm_sequence = switch_strand(ADN_sequence)
print(ARNm_sequence)
# Out:
# AUGAGGACA

# %% [markdown]
# # Task 2
# In this Task we will complete the program code to fully translate the DNA sequence into the according protein.
#
# __2a\)__
# Translate the ``ARNm`` sequence from __Task 1__ into the corresponding ``protein`` sequence _by hand with pen und paper_.
# __Hint:__ Use the genetic table shown <span style="color:cyan">step 2</span>.
#
#
# __2b)__
# Write a Python program code that takes the ``ADN_brin_2`` produces a ``mRNA`` sequence by executing <span style="color:cyan">step 2</span>. Use your previous results from __stage 1__ as a guide and compare the resulting sequence with the one you got in __Task 2a__.
#
# __2c)__
# Investigate the ``translate_genetic_sequence`` function and take notes. Do you understand what it does? If not, just ask the Chatbot.
# Then run the ``translate_genetic_sequence`` function using the ``mRNA`` sequence to produce a ``polypeptide`` sequence. Does it match your previous results.

# %%
# Définir un dictionnaire pour les codons et les acides aminés correspondants.
codon_table = {
    "UUU": "Phe", "UUC": "Phe", "UUA": "Leu", "UUG": "Leu",
    "CUU": "Leu", "CUC": "Leu", "CUA": "Leu", "CUG": "Leu",
    "AUU": "Ile", "AUC": "Ile", "AUA": "Ile", "AUG": "Met",
    "GUU": "Val", "GUC": "Val", "GUA": "Val", "GUG": "Val",
    "UCU": "Ser", "UCC": "Ser", "UCA": "Ser", "UCG": "Ser",
    "CCU": "Pro", "CCC": "Pro", "CCA": "Pro", "CCG": "Pro",
    "ACU": "Thr", "ACC": "Thr", "ACA": "Thr", "ACG": "Thr",
    "GCU": "Ala", "GCC": "Ala", "GCA": "Ala", "GCG": "Ala",
    "UAU": "Tyr", "UAC": "Tyr", "UAA": "FIN", "UAG": "FIN",
    "CAU": "His", "CAC": "His", "CAA": "Gln", "CAG": "Gln",
    "AAU": "Asn", "AAC": "Asn", "AAA": "Lys", "AAG": "Lys",
    "GAU": "Asp", "GAC": "Asp", "GAA": "Glu", "GAG": "Glu",
    "UGU": "Cys", "UGC": "Cys", "UGA": "FIN", "UGG": "Trp",
    "CGU": "Arg", "CGC": "Arg", "CGA": "Arg", "CGG": "Arg",
    "AGU": "Ser", "AGC": "Ser", "AGA": "Arg", "AGG": "Arg",
    "GGU": "Gly", "GGC": "Gly", "GGA": "Gly", "GGG": "Gly",
}

# %%
# Function to translate a genetic sequence into a protein
def translate_genetic_sequence(sequence):
    polypeptide = ""
    for i in range(0, len(sequence), 3):
        codon = sequence[i:i+3]
        amino_acid = codon_table.get(codon, "-")
        if amino_acid == "FIN":
            break
        else:
            polypeptide += amino_acid

    return polypeptide

polypeptide = translate_genetic_sequence(ARNm_sequence)
print(f"Polypeptide: {polypeptide}")
# Out:
# Polypeptide: MetArgThr

# %% [markdown]
# # Stage 3
# In this final stage we will find out which of the DNA sequences ``ADN_sequence_1`` and ``ADN_sequence_2`` is the original version and which is the mutated version of the zebra fish gene.
#
# ## Tasks
# __3a)__
# In the beginning we used the short DNA sequence ``ATGAGGACA``, now replace it with ``ADN_sequence_1`` and run the following cell. Note the length of the polypeptide sequence and repeat the same with ``ADN_sequence_2``.
#
# The length of the two polypeptide sequences should be different. That your results from Task 3a do not reflect that, is because the ``translate_genetic_sequence`` function does not finish the sequence, if the stop codons ``UAA``, ``UAG`` or ``UGA`` appear.
#
# __3b)__
# Find out what the ``translate_genetic_sequence`` function appends to the ``polypeptide`` when it processes a stop codon. Therefore Investigate the codon table.
# Using this information, implement a If Else statement into the ``translate_genetic_sequence`` function so it stops, when a stop codon is processed. Ask the chatbot if you need help.
#
# __3c)__
# Check again the length of ``ADN_sequence_1`` and ``ADN_sequence_2``. Can you tell now which sequence is the original and which is the mutated version?
# If yes, well done you are a programming genie and well prepared to study bio informatics.

# %%
# Translate the genetic sequence into a protein
polypeptide = translate_genetic_sequence(ARNm_sequence)

# Display the translated protein sequence
print("Translated polypeptide sequence:", polypeptide)
print("Length of polypeptide sequence:", int(len(polypeptide)/3))
