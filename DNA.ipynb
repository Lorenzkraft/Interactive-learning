# %%
RNA_sequence = open("C:/Users/Lorenz/Machine Learning/Interactive-learning/RNA_sequences.edi", "r")
RNA_sequence = RNA_sequence.read()

#RNA_sequence.close()

# %%
RNA_sequence
# Out:
# '; Anagène - Fenêtre Edition\n; Danio-Rayures-Sombres cpl ARN\n; Type 2\n; Dec  0\n; \\nUAUAAGGUCCUACUAAGACCUAUAAGUGUAGAUAGCGAGUCGGACGU
# ...
