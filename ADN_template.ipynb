# %%
from utils.FilePreparator import ADN_sequence_1, ADN_sequence_2

# %% [markdown]
# # Commencer ici
# L'évolution est l'histoire d'un changement au fil du temps, et au cœur de tout cela se trouve l'ADN. Tout comme une faute de frappe dans un livre peut en changer le sens, les mutations de l'ADN peuvent modifier les protéines pour lesquelles il est codé, ce qui se traduit par des caractéristiques différentes chez les organismes vivants. Aujourd'hui, nous allons nous mettre dans la peau de biologistes de l'évolution et explorer comment des changements, même minimes, dans les séquences d'ADN peuvent entraîner des variations spectaculaires dans l'apparence de l'organisme concerné. Préparez-vous à plonger dans le code de la vie et à découvrir les mécanismes qui sous-tendent l'évolution génétique !
# # Contexte biologique
# ## Le poisson zèbre
# Zebre poisson ...
#
# ## Traduction biologique
# Une façon de distinguer les deux séquences génétiques du poisson zèbre est de les traduire en leur protéine correspondante. Récapitulons d'abord comment la traduction se fait en théorie.
#
# Pour traduire une séquence d'ADN en la protéine correspondante (chaîne d'acides aminés), deux étapes sont nécessaires. Tout d'abord, nous devons transcrire la séquence d'ADN en sa séquence complémentaire d'ARNm.
# Cette transcription s'effectue lors de l'étape 1 : <span style="color:orange">l'étape 2 : </span>.
#
# Les bases doivent être remplacées par leurs équivalents et le "A" est remplacé par le "U" :
#
# <div style="background-color: orange; padding: 10px;">
#     <table style="color: black;">
#         <tr>
#             <th>ADN</th>
#             <th>ARNm</th>
#         </tr>
#         <tr>
#             <td>A</td>
#             <td>U</td>
#         </tr>
#         <tr>
#             <td>T</td>
#             <td>A</td>
#         </tr>
#         <tr>
#             <td>G</td>
#             <td>C</td>
#         </tr>
#         <tr>
#             <td>C</td>
#             <td>G</td>
#         </tr>
#     </table>
# </div>
#
#
#
#
# <span style="color:cyan">Step 2:</span>
# La séquence d'ARNm doit maintenant être traduite en la protéine correspondante.
# Dans cette étape, nous utilisons le code génétique pour traduire la séquence en protéine.
# <div style="background-color: lightblue">
#     <img src="./utils/genetic-code-RNA-BW.png" alt="Alt text" width="300"/>
# </div>
#
#
# ## Buts
# Comme la traduction prendrait beaucoup trop de temps à la main, nous voulons écrire un code de programme avec le langage de programmation "Python" qui fait le travail à notre place. Vous n'avez jamais programmé auparavant ? Pas de problème, il vous suffit de suivre ce modèle et vous apprendrez :
# 1. intuitivement comment traduire le code génétique à la main.
# 2. de manière interactive comment transférer votre procédure en code.

# %% [markdown]
# # Tâche 1
# Dans la première tâche, notre objectif est de traduire une courte séquence d'ADN à la main et de transférer notre procédure dans le code du programme :
#
# __1a\)__
# Transcrire la séquence d'ADN ``ADN = TACTCGT`` en la séquence ``ARNm`` selon <span style="color:orange">l'étape 1</span> _à la main avec un stylo et du papier_.
#
# __1b\)__
# Examinez le code suivant et essayez de comprendre ce que fait chaque ligne.
# Si vous avez besoin d'aide, ouvrez le fichier ``Robofriend.ipynb`` dans un autre onglet et commencez une conversation avec le chatbot.
# Il n'a pas d'informations sur le contexte, alors copiez et collez le code et demandez-lui s'il peut vous aider à comprendre le code.
#
# __1c\)__
# Sur la base de votre compréhension et de l'aide du "Chatbot", transférer la logique de la liste de courses à un algorithme qui transcrit la séquence d'ADN de la __Tâche 1a__.
# Votre code devrait produire une séquence appelée "ARNm". Correspond-elle à votre résultat de la __Tâche 1a__ ?
# Si oui, vous pouvez passer à la tâche suivante,
# Sinon, essayez de trouver l'erreur vous-même ou demandez de l'aide à votre professeur.

# %%
courses_en_anglais = "apple banana pear grape ".split(" ") # supprimer .split(" ") lorsque vous modifiez le code de la tâche 1c)

dictionaire_anglais_francais = {
    "apple": "pomme",
    "banana": "banane",
    "pear": "poire",
    "grape": "raisin"
}
courses_en_fr = ""

for item in courses_en_anglais:
    traduction_fr = dictionaire_anglais_francais.get(item, "")
    courses_en_fr += traduction_fr + " " # remove + " " lorsque vous modifiez le code de la tâche 1c)
print(courses_en_fr)
# Out:
# pomme banane poire raisin

# %%
# Définis la séquence d'ADN que tu veux traduire.
ADN = "TACATCTGT"

# %%
# Définir le dictionnaire de transcriptions.
Dictionaire_ADN_en_ARNm = {...} # Remplace les ... par le dictionnaire de transcriptions.

# %%
# Transcrire l'ADN en ARNm.
# Out:
# AUGUAGACA

# %% [markdown]
# # Tâche 2
# Dans cette tâche, nous compléterons le code du programme pour traduire complètement la séquence d'ADN en la protéine correspondante.
#
# __2a\)__
# Traduisez la séquence ``ARNm`` de la __Tâche 1__ en la séquence ``protéine`` correspondante _à la main avec un stylo et du papier_.
# Combien d'acides aminés contient la protéine ?
# Utilisez le tableau génétique montré <span style="color:cyan">étape 2</span>.
#
#
# __2b)__
# Examinez les deux cellules de code sur la traduction des protéines ci-dessous (ignorez la cellule suivante) et essayez de comprendre ce que fait chaque ligne de code.
# Exécutez le code et comparez le résultat avec le vôtre : est-ce le même ?
# _Si oui_, alors vous avez fait quelque chose d'__incorrect__ dans la __Tâche 2a__.
# _Si non_, expliquez ce que le code fait de mal et ce qu'il devrait faire à la place.
#
# __2c)__
# Nous voulons maintenant corriger le code.
# Inspectez donc le code de la liste d'achats ci-dessous. Il est presque identique à celui de la __Tâche 1__, mais en quoi diffère-t-il ?
#
# __2d)__
# Modifiez le code de traduction des protéines, afin qu'il produise le même résultat que celui que vous avez obtenu à la main.
# __Conseil__ : Utilisez les connaissances que vous avez acquises lors de la __Tâche 2c__ et si vous avez besoin de plus d'aide, demandez au Chatbot.

# %%
# Définir un dictionnaire pour les codons et les acides aminés correspondants.
codon_table = {
    "UUU": "Phe", "UUC": "Phe", "UUA": "Leu", "UUG": "Leu",
    "CUU": "Leu", "CUC": "Leu", "CUA": "Leu", "CUG": "Leu",
    "AUU": "Ile", "AUC": "Ile", "AUA": "Ile", "AUG": "Met",
    "GUU": "Val", "GUC": "Val", "GUA": "Val", "GUG": "Val",
    "UCU": "Ser", "UCC": "Ser", "UCA": "Ser", "UCG": "Ser",
    "CCU": "Pro", "CCC": "Pro", "CCA": "Pro", "CCG": "Pro",
    "ACU": "Thr", "ACC": "Thr", "ACA": "Thr", "ACG": "Thr",
    "GCU": "Ala", "GCC": "Ala", "GCA": "Ala", "GCG": "Ala",
    "UAU": "Tyr", "UAC": "Tyr", "UAA": "STP", "UAG": "STP",
    "CAU": "His", "CAC": "His", "CAA": "Gln", "CAG": "Gln",
    "AAU": "Asn", "AAC": "Asn", "AAA": "Lys", "AAG": "Lys",
    "GAU": "Asp", "GAC": "Asp", "GAA": "Glu", "GAG": "Glu",
    "UGU": "Cys", "UGC": "Cys", "UGA": "STP", "UGG": "Trp",
    "CGU": "Arg", "CGC": "Arg", "CGA": "Arg", "CGG": "Arg",
    "AGU": "Ser", "AGC": "Ser", "AGA": "Arg", "AGG": "Arg",
    "GGU": "Gly", "GGC": "Gly", "GGA": "Gly", "GGG": "Gly",
}

# %%
# Algorithme de traduction d'une séquence génétique en protéine
protein = ""
for i in range(0, len(ARNm), 3):
    codon = ARNm[i:i+3]
    amino_acid = codon_table.get(codon, "-")
    protein += amino_acid

print(f"protein: {protein}")
# Out:
# Polypeptide: MetSTPThr

# %%
# Exercice 2c
courses_en_anglais = "apple banana pear grape ".split(" ") 

dictionaire_anglais_francais = {
    "apple": "pomme",
    "banana": "banane",
    "pear": "poire",
    "grape": "raisin"
}
courses_en_fr = ""

for item in courses_en_anglais:
    traduction_fr = dictionaire_anglais_francais.get(item, "")
    if traduction_fr == "poire":    # Ici, nous avons ajouté une condition pour arrêter la boucle
        break
    else:
        courses_en_fr += traduction_fr + " " 
print(courses_en_fr)
# Out:
# pomme banane

# %% [markdown]
# # Tâche 3
# Dans cette tâche finale, nous allons mettre notre code à l'épreuve. En déterminant la longueur de la protéine résultante à partir des séquences d'ADN ``ADN_séquence_1`` et ``ADN_séquence_2``, nous découvrirons quelle est la version originale et quelle est la version mutée du gène du poisson zèbre.
#
# __3a)__
# Remplacez la courte séquence d'ADN ``TACATCTGT`` au début par ``ADN_séquence_1`` et exécutez la cellule suivante.
# Notez la longueur de la protéine et répétez la même chose avec `ADN_séquence_2`.
#
# __3b)__
# Trouvez et expliquez quelle est la séquence d'ADN originale et quelle est la séquence mutée. Montrez le résultat à votre professeur.
#
# __Pour les plus rapides : 3c)__
# Avez-vous déjà pensé à vous lancer dans la bio-informatique et à utiliser Python ? C'est l'occasion ou jamais ! Demandez au chatbot tout ce que vous voulez, collectez des idées et commencez à réfléchir à la façon dont vous pourriez en faire un <span style="color:red">r</span><span style="color:orange">e</span><span style="color :jaune">a</span><span style="color:lightgreen">l</span><span style="color:cyan">i</span><span style="color:magenta">t</span><span style="color:pink">y</span> !

# %%
# Afficher la séquence de la protéine traduite
print("Séquence protéique traduite :", protein)
print("Longueur de la séquence protéique :", int(len(protein)/3))
